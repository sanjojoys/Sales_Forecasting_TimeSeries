# %%
##EDA

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the cleaned data
sales = pd.read_csv("/Users/sanjojoy/Desktop/Git_repositories/Sales forecasting/data/cleaned_sales_data.csv", index_col="date", parse_dates=True)

# Plot the sales data
plt.figure(figsize=(12, 6))
plt.plot(sales.index, sales['sales'], label="Sales")
plt.title("Daily Sales")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()
plt.show()

# %%
##Header
import pandas as pd

# Load the CSV file without setting the index
file_path = "/Users/sanjojoy/Desktop/Git_repositories/Sales forecasting/data/cleaned_sales_data.csv"
data = pd.read_csv(file_path)

# Print the first few rows and column names
print("Columns in the CSV file:", data.columns)
print(data.head())

data.columns = data.columns.str.strip()
# Out:
# Columns in the CSV file: Index(['date', 'store', 'item', 'sales'], dtype='object')
#          date  store   item  sales
# 0  2013-01-01   2750  12750  13696
# 1  2013-01-02   2750  12750  13678
# 2  2013-01-03   2750  12750  14488
# 3  2013-01-04   2750  12750  15677
# 4  2013-01-05   2750  12750  16237

# %%
##Time_series_analysis

from statsmodels.tsa.seasonal import seasonal_decompose

# Decompose the time series
result = seasonal_decompose(sales['sales'], model='additive', period=365)

# Plot decomposition
result.plot()
plt.show()
