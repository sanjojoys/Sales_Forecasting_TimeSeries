# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import pandas as pd
# Load the cleaned data
sales = pd.read_csv("/Users/sanjojoy/Desktop/Git_repositories/Sales forecasting/data/cleaned_sales_data.csv", index_col="date", parse_dates=True)

# Decompose the time series
result = seasonal_decompose(sales['sales'], model='additive', period=365)

# Plot decomposition
result.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       9 # Plot decomposition
#      10 result.plot()
# ---> 11 plt.show()
#
# NameError: name 'plt' is not defined

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import numpy as np
import pandas as pd 

file_path = "/Users/sanjojoy/Desktop/Git_repositories/Sales forecasting/data/cleaned_sales_data.csv"
sales = pd.read_csv(file_path)

# Ensure 'sales' column exists
print("Columns in the data:", sales.columns)

# Convert 'date' to datetime if needed and set it as the index
if 'date' in sales.columns:
    sales['date'] = pd.to_datetime(sales['date'])
    sales.set_index('date', inplace=True)

# Check the data structure
print(sales.head())

# Define the ARIMA model
model = ARIMA(sales['sales'], order=(5, 1, 0))  # (p, d, q)
model_fit = model.fit()

# Forecast
forecast = model_fit.forecast(steps=30)
print(forecast)
# Out:
# Columns in the data: Index(['date', 'store', 'item', 'sales'], dtype='object')
#             store   item  sales
# date
# 2013-01-01   2750  12750  13696
# 2013-01-02   2750  12750  13678
# 2013-01-03   2750  12750  14488
# 2013-01-04   2750  12750  15677
# 2013-01-05   2750  12750  16237
# 2018-01-01    23557.582456
# 2018-01-02    22675.654436
# 2018-01-03    22447.923884
# 2018-01-04    23069.917413
# 2018-01-05    24172.873926
# 2018-01-06    24750.101390
# 2018-01-07    24066.810285
# 2018-01-08    23487.934500
# 2018-01-09    23088.116625
# 2018-01-10    23227.476091
# 2018-01-11    23731.780378
# 2018-01-12    24074.837953
# 2018-01-13    23989.320371
# 2018-01-14    23726.906022
# 2018-01-15    23460.109909
# 2018-01-16    23428.299363
# 2018-01-17    23609.066141
# 2018-01-18    23798.107794
# 2018-01-19    23846.177914
# 2018-01-20    23759.688532
# 2018-01-21    23623.375252
# 2018-01-22    23563.425330
# 2018-01-23    23609.056321
# 2018-01-24    23697.390020
# ...

# %%
# Convert 'date' to datetime if needed and set it as the index
if 'date' in sales.columns:
    sales['date'] = pd.to_datetime(sales['date'])
    sales.set_index('date', inplace=True)

# Check the data structure
print(sales.head())
# Out:
#             store   item  sales
# date
# 2013-01-01   2750  12750  13696
# 2013-01-02   2750  12750  13678
# 2013-01-03   2750  12750  14488
# 2013-01-04   2750  12750  15677
# 2013-01-05   2750  12750  16237

# %%
# Convert 'date' to datetime if needed and set it as the index
if 'date' in sales.columns:
    sales['date'] = pd.to_datetime(sales['date'])
    sales.set_index('date', inplace=True)

# Check the data structure
print(sales.head())
# Out:
#             store   item  sales
# date
# 2013-01-01   2750  12750  13696
# 2013-01-02   2750  12750  13678
# 2013-01-03   2750  12750  14488
# 2013-01-04   2750  12750  15677
# 2013-01-05   2750  12750  16237

# %%
# Define the ARIMA model
model = ARIMA(sales['sales'], order=(5, 1, 0))  # (p, d, q)

# Fit the model
model_fit = model.fit()

# Summarize the results
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  sales   No. Observations:                 1826
# Model:                 ARIMA(5, 1, 0)   Log Likelihood              -17537.646
# Date:                Sun, 24 Nov 2024   AIC                          35087.291
# Time:                        00:40:02   BIC                          35120.347
# Sample:                    01-01-2013   HQIC                         35099.485
#                          - 12-31-2017
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5981      0.046    -12.869      0.000      -0.689      -0.507
# ar.L2         -0.4137      0.052     -7.928      0.000      -0.516      -0.311
# ar.L3         -0.4622      0.047     -9.791      0.000      -0.555      -0.370
# ...
